# %%
import pandas as pd
import numpy as np
import re
import dateparser
from collections import Counter

import warnings
warnings.filterwarnings('ignore')

# %%
def read_file(file):
    '''Reads Whatsapp text file into a list of strings''' 
    x = open(file,'r', encoding = 'utf-8') #Opens the text file into variable x but the variable cannot be explored yet
    y = x.read() #By now it becomes a huge chunk of string that we need to separate line by line
    content = y.splitlines() #The splitline method converts the chunk of string into a list of strings
    return content

# %%
chat = read_file('Chat.txt')
len(chat)
# Out:
# 3198

# %%
join = [line for line in chat if  "joined using this" in line]
join
# Out:
# ["04/08/2022, 2:12 pm - You joined using this group's invite link",
#  "04/08/2022, 2:54 pm - +234 803 568 5324 joined using this group's invite link",
#  "04/08/2022, 2:57 pm - Benji joined using this group's invite link",
#  "04/08/2022, 3:16 pm - Mash joined using this group's invite link",
#  "04/08/2022, 3:19 pm - +234 706 767 8201 joined using this group's invite link",
#  "04/08/2022, 3:22 pm - +234 806 234 7970 joined using this group's invite link",
#  "04/08/2022, 3:40 pm - +234 803 570 5272 joined using this group's invite link",
#  "04/08/2022, 4:18 pm - +234 813 038 2293 joined using this group's invite link",
#  "04/08/2022, 4:26 pm - +234 912 185 6837 joined using this group's invite link",
#  "04/08/2022, 4:32 pm - +234 813 890 9679 joined using this group's invite link",
#  "04/08/2022, 6:28 pm - +234 806 827 3129 joined using this group's invite link",
#  "04/08/2022, 6:32 pm - +234 806 884 2448 joined using this group's invite link",
#  "04/08/2022, 8:09 pm - +234 816 258 3465 joined using this group's invite link",
#  "04/08/2022, 8:16 pm - +234 813 893 6359 joined using this group's invite link",
#  "04/08/2022, 8:19 pm - +234 706 567 0728 joined using this group's invite link",
#  "04/08/2022, 8:42 pm - +234 810 573 5646 joined using this group's invite link",
#  "04/08/2022, 9:51 pm - +234 703 745 0166 joined using this group's invite link",
#  "04/08/2022, 10:08 pm - +234 814 960 2831 joined using this group's invite link",
#  "04/08/2022, 11:15 pm - +234 813 551 6244 joined using this group's invite link",
#  "05/08/2022, 8:13 am - +234 816 498 8135 joined using this group's invite link",
#  "05/08/2022, 8:14 am - +234 706 502 3994 joined using this group's invite link",
#  "05/08/2022, 8:39 am - +234 813 484 3106 joined using this group's invite link",
#  "05/08/2022, 9:18 am - +234 703 586 6325 joined using this group's invite link",
#  "05/08/2022, 10:03 am - +234 814 505 2451 joined using this group's invite link",
#  "05/08/2022, 2:47 pm - +234 806 010 4979 joined using this group's invite link",
#  "05/08/2022, 3:09 pm - +234 915 075 3046 joined using this group's invite link",
#  "05/08/2022, 4:56 pm - +234 810 932 9474 joined using this group's invite link",
#  "05/08/2022, 5:25 pm - +234 807 050 1490 joined using this group's invite link",
#  "05/08/2022, 7:11 pm - +234 703 645 3540 joined using this group's invite link",
#  "05/08/2022, 7:28 pm - +234 813 408 4085 joined using this group's invite link",
#  "05/08/2022, 7:46 pm - +234 809 775 0408 joined using this group's invite link",
#  "05/08/2022, 9:19 pm - +234 703 541 8008 joined using this group's invite link",
#  "07/08/2022, 9:11 am - Big Wizzy joined using this group's invite link",
#  "07/08/2022, 7:12 pm - Chidera Code Plateau joined using this group's invite link",
#  "09/08/2022, 9:30 am - +234 701 936 6781 joined using this group's invite link",
#  "09/08/2022, 9:33 am - +234 814 746 6901 joined using this group's invite link",
#  "09/08/2022, 9:34 am - +234 803 732 7281 joined using this group's invite link",
#  "09/08/2022, 9:34 am - +234 813 824 1165 joined using this group's invite link",
#  "09/08/2022, 9:39 am - +234 806 174 4121 joined using this group's invite link",
#  "09/08/2022, 9:39 am - Zhingak… joined using this group's invite link",
#  "09/08/2022, 10:05 am - +234 813 846 8779 joined using this group's invite link",
#  "09/08/2022, 10:34 am - +234 704 457 6626 joined using this group's invite link",
#  "09/08/2022, 3:51 pm - +234 806 911 7233 joined using this group's invite link",
#  "10/08/2022, 12:06 pm - +234 703 689 8466 joined using this group's invite link",
#  "10/08/2022, 6:52 pm - +234 816 504 5090 joined using this group's invite link",
#  "16/08/2022, 1:36 pm - +234 906 629 7064 joined using this group's invite link",
#  "12/10/2022, 8:22 am - Jabezi Code Plateau joined using this group's invite link"]

# %% [markdown]
# We will clean our chat data by removing all messages in join and also by removing all empty lines (lines that contain no message) by running the code below:

# %%
#Remove new lines
chat = [line.strip() for line in chat]
print("length of chat is:")
print(len(chat))
#Clean out the join notification lines
clean_chat = [line for line in chat if not "joined using this" in line]
#Further cleaning
#Remove empty lines
clean_chat = [line for line in clean_chat if len(line) > 1]
print("length of clean_chat is:")
print(len(clean_chat))
# Out:
# length of chat is:
# 3198
# length of clean_chat is:
# 2869

# %%
#Drop 'left-ers'
left = [line for line in clean_chat if line.endswith("left")]
left
# Out:
# ['19/08/2022, 12:16 am - Benji left',
#  '09/09/2022, 7:52 am - +234 806 010 4979 left',
#  '23/09/2022, 6:26 pm - +234 803 568 5324 left']

# %%
#Clean out the left notification lines
clean_chat = [line for line in clean_chat if not line.endswith("left")]
print(len(clean_chat))
# Out:
# 2866

# %%
#Merge messages that belong together
msgs = [] #message container
pos = 0 #counter for position of msgs in the container
"""
Flow:
For every line, see if it matches the expression which is starting with the format "number(s)+slash" eg "12/"
If it does, it is a new line of conversion as they begin with dates, add it to msgs container
Else, it is a continuation of the previous line, add it to the previous line and append to msgs, then pop previous line.
"""
for line in clean_chat:
    if re.findall("\A\d+[/]", line):
        msgs.append(line)
        pos += 1
    else:
        take = msgs[pos-1] + ". " + line
        msgs.append(take)
        msgs.pop(pos-1)
len(msgs)
# Out:
# 2023

# %%
msgs[0:10]
# Out:
# ['04/08/2022, 2:12 pm - Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. Tap to learn more.',
#  '04/08/2022, 12:05 pm - +234 813 215 5650 created group "CodePlateau4.0DataScience"',
#  '04/08/2022, 3:02 pm - +234 814 838 1223 added +234 802 253 0435',
#  '04/08/2022, 3:18 pm - +234 814 838 1223 added +234 806 892 9315',
#  '04/08/2022, 3:41 pm - +234 803 570 5272: Please, can you send the document for today?',
#  '04/08/2022, 4:20 pm - +234 806 451 1186: Calm down',
#  '04/08/2022, 4:28 pm - +234 806 234 7970: Thanks for the link and for adding me',
#  '04/08/2022, 10:11 pm - Jabezy Code Plateau: <Media omitted>',
#  "04/08/2022, 10:12 pm - +234 813 215 5650 changed this group's icon",
#  "05/08/2022, 6:14 am - +234 814 838 1223 changed this group's icon"]

# %% [markdown]
# Next, we will need to extract Date, Time, Name and Message Content from our msgs data using the codes below:

# %%
time = [msgs[i].split(',')[1].split('-')[0] for i in range(len(msgs))]
time = [s.strip(' ') for s in time] # Remove spacing
print("length of time is:")
print(len(time))
time
# Out:
# length of time is:
# 2023
# ['2:12 pm',
#  '12:05 pm',
#  '3:02 pm',
#  '3:18 pm',
#  '3:41 pm',
#  '4:20 pm',
#  '4:28 pm',
#  '10:11 pm',
#  '10:12 pm',
#  '6:14 am',
#  '10:56 am',
#  '11:01 am',
#  '11:02 am',
#  '11:03 am',
#  '11:05 am',
#  '11:19 am',
#  '11:56 am',
#  '12:09 pm',
#  '2:48 pm',
#  '5:41 pm',
#  '5:44 pm',
#  '7:00 pm',
#  '7:02 pm',
#  '7:07 pm',
#  '7:20 pm',
#  '7:39 pm',
#  '7:39 pm',
#  '7:39 pm',
#  '7:43 pm',
#  '7:45 pm',
#  '7:54 pm',
#  '7:59 pm',
#  '8:05 pm',
#  '8:05 pm',
#  '8:06 pm',
#  '8:06 pm',
#  '8:53 pm',
#  '6:44 am',
#  '2:17 pm',
#  '2:17 pm',
#  '2:17 pm',
#  '2:38 pm',
#  '2:42 pm',
#  '2:50 pm',
#  '2:53 pm',
#  '2:53 pm',
#  '2:54 pm',
#  '3:02 pm',
#  '3:04 pm',
#  '3:58 pm',
#  '3:58 pm',
#  '11:22 am',
#  '8:14 am',
#  '8:15 am',
#  '9:30 am',
#  '9:36 am',
#  '9:41 am',
#  '10:06 am',
#  '10:07 am',
#  '10:07 am',
#  '1:11 pm',
#  '1:35 pm',
#  '2:35 pm',
#  '2:39 pm',
#  '3:04 pm',
#  '3:51 pm',
#  '3:51 pm',
#  '4:15 pm',
#  '5:29 pm',
#  '5:41 pm',
#  '5:44 pm',
#  '9:23 pm',
#  '12:37 pm',
#  '12:37 pm',
#  '12:56 pm',
#  '12:59 pm',
#  '1:00 pm',
#  '1:00 pm',
#  '2:07 pm',
#  '2:07 pm',
#  '2:09 pm',
#  '2:14 pm',
#  '2:29 pm',
#  '2:31 pm',
#  '2:40 pm',
#  '5:06 pm',
#  '9:43 am',
#  '9:44 am',
#  '9:49 am',
#  '9:49 am',
#  '9:49 am',
#  '9:49 am',
#  '9:49 am',
#  '9:49 am',
#  '9:49 am',
#  '9:49 am',
#  '9:49 am',
#  '9:49 am',
#  '9:49 am',
#  '9:49 am',
#  '9:49 am',
#  '9:49 am',
#  '9:49 am',
#  '9:49 am',
#  '9:49 am',
#  '9:49 am',
#  '9:55 am',
#  '10:00 am',
#  '10:05 am',
#  '10:06 am',
#  '10:06 am',
#  '10:09 am',
#  '10:10 am',
#  '10:10 am',
#  '10:10 am',
#  '10:57 am',
#  '11:26 am',
#  '11:37 am',
#  '11:55 am',
#  '12:03 pm',
#  '12:49 pm',
#  '10:56 pm',
#  '11:00 pm',
#  '11:01 pm',
#  '11:02 pm',
#  '11:06 pm',
#  '11:10 pm',
#  '11:15 pm',
#  '11:17 pm',
#  '11:17 pm',
#  '11:18 pm',
#  '12:21 pm',
#  '1:43 pm',
#  '2:03 pm',
#  '2:33 pm',
#  '3:06 pm',
#  '3:06 pm',
#  '3:07 pm',
#  '3:09 pm',
#  '4:37 pm',
#  '4:37 pm',
#  '4:37 pm',
#  '4:42 pm',
#  '4:48 pm',
#  '4:57 pm',
#  '5:00 pm',
#  '5:01 pm',
#  '5:01 pm',
#  '5:01 pm',
#  '5:02 pm',
#  '5:02 pm',
#  '5:03 pm',
#  '5:04 pm',
#  '5:04 pm',
#  '5:05 pm',
#  '5:06 pm',
#  '5:08 pm',
#  '5:08 pm',
#  '5:11 pm',
#  '5:21 pm',
#  '5:21 pm',
#  '5:23 pm',
#  '5:24 pm',
#  '5:24 pm',
#  '5:26 pm',
#  '5:28 pm',
#  '5:29 pm',
#  '6:20 pm',
#  '6:21 pm',
#  '6:25 pm',
#  '6:25 pm',
#  '6:40 pm',
#  '6:57 pm',
#  '7:39 pm',
#  '9:56 pm',
#  '9:57 pm',
#  '9:59 pm',
#  '10:01 pm',
#  '10:02 pm',
#  '10:12 pm',
#  '10:13 pm',
#  '10:26 pm',
#  '4:30 pm',
#  '4:33 pm',
#  '4:33 pm',
#  '4:34 pm',
#  '4:35 pm',
#  '4:35 pm',
#  '4:36 pm',
#  '4:37 pm',
#  '4:37 pm',
#  '4:37 pm',
#  '4:38 pm',
#  '4:38 pm',
#  '4:41 pm',
#  '4:41 pm',
#  '4:41 pm',
#  '4:42 pm',
#  '4:42 pm',
#  '4:43 pm',
#  '4:43 pm',
#  '4:44 pm',
#  '4:45 pm',
#  '4:45 pm',
#  '4:46 pm',
#  '8:19 am',
#  '8:21 am',
#  '8:25 am',
#  '8:25 am',
#  '8:25 am',
#  '8:26 am',
#  '8:28 am',
#  '8:43 am',
#  '8:48 am',
#  '8:49 am',
#  '9:03 am',
#  '9:09 am',
#  '9:11 am',
#  '9:13 am',
#  '9:17 am',
#  '9:17 am',
#  '9:20 am',
#  '9:50 am',
#  '9:51 am',
#  '9:53 am',
#  '9:56 am',
#  '9:56 am',
#  '10:07 am',
#  '10:11 am',
#  '10:11 am',
#  '10:11 am',
#  '10:13 am',
#  '10:13 am',
#  '10:14 am',
#  '10:14 am',
#  '10:14 am',
#  '10:15 am',
#  '10:16 am',
#  '10:22 am',
#  '11:23 am',
#  '11:27 am',
#  '11:52 am',
#  '11:52 am',
#  '11:52 am',
#  '11:52 am',
#  '11:59 am',
#  '11:59 am',
#  '11:59 am',
#  '12:10 pm',
#  '12:10 pm',
#  '12:15 pm',
#  '12:16 pm',
#  '12:17 pm',
#  '12:19 pm',
#  '12:22 pm',
#  '1:00 pm',
#  '1:28 pm',
#  '1:29 pm',
#  '1:30 pm',
#  '1:34 pm',
#  '1:36 pm',
#  '1:37 pm',
#  '3:25 pm',
#  '3:26 pm',
#  '3:27 pm',
#  '3:27 pm',
#  '3:28 pm',
#  '3:28 pm',
#  '5:34 pm',
#  '5:38 pm',
#  '5:38 pm',
#  '11:28 am',
#  '11:29 am',
#  '11:31 am',
#  '11:32 am',
#  '11:32 am',
#  '11:32 am',
#  '11:33 am',
#  '11:34 am',
#  '11:35 am',
#  '11:36 am',
#  '11:38 am',
#  '11:39 am',
#  '11:39 am',
#  '11:39 am',
#  '11:40 am',
#  '11:40 am',
#  '8:58 am',
#  '9:17 am',
#  '9:22 am',
#  '12:32 pm',
#  '12:32 pm',
#  '1:50 pm',
#  '1:51 pm',
#  '1:51 pm',
#  '1:51 pm',
#  '2:11 pm',
#  '5:15 pm',
#  '5:15 pm',
#  '5:27 pm',
#  '5:56 pm',
#  '6:28 pm',
#  '6:29 pm',
#  '6:29 pm',
#  '6:34 pm',
#  '8:24 pm',
#  '8:27 pm',
#  '8:32 pm',
#  '11:34 pm',
#  '4:41 pm',
#  '8:48 pm',
#  '9:33 pm',
#  '9:33 pm',
#  '9:35 pm',
#  '9:41 pm',
#  '9:48 pm',
#  '9:49 pm',
#  '9:50 pm',
#  '9:50 pm',
#  '9:51 pm',
#  '9:52 pm',
#  '10:00 pm',
#  '10:03 pm',
#  '10:04 pm',
#  '10:05 pm',
#  '10:06 pm',
#  '10:06 pm',
#  '10:06 pm',
#  '10:06 pm',
#  '10:06 pm',
#  '10:07 pm',
#  '10:09 pm',
#  '10:13 pm',
#  '10:15 pm',
#  '10:16 pm',
#  '10:16 pm',
#  '10:17 pm',
#  '10:17 pm',
#  '10:19 pm',
#  '11:44 pm',
#  '1:22 pm',
#  '1:24 pm',
#  '2:13 pm',
#  '2:16 pm',
#  '2:18 pm',
#  '2:18 pm',
#  '2:19 pm',
#  '2:20 pm',
#  '2:42 pm',
#  '2:47 pm',
#  '5:14 pm',
#  '5:15 pm',
#  '5:16 pm',
#  '5:18 pm',
#  '5:20 pm',
#  '5:20 pm',
#  '5:20 pm',
#  '5:20 pm',
#  '5:21 pm',
#  '5:21 pm',
#  '5:21 pm',
#  '5:21 pm',
#  '5:22 pm',
#  '5:22 pm',
#  '5:23 pm',
#  '5:24 pm',
#  '5:28 pm',
#  '5:28 pm',
#  '5:29 pm',
#  '5:29 pm',
#  '5:30 pm',
#  '5:30 pm',
#  '5:30 pm',
#  '5:31 pm',
#  '5:33 pm',
#  '5:33 pm',
#  '5:33 pm',
#  '5:34 pm',
#  '5:34 pm',
#  '5:34 pm',
#  '5:35 pm',
#  '5:45 pm',
#  '5:58 pm',
#  '5:58 pm',
#  '5:59 pm',
#  '6:00 pm',
#  '6:00 pm',
#  '6:02 pm',
#  '6:02 pm',
#  '6:09 pm',
#  '6:26 pm',
#  '6:28 pm',
#  '6:29 pm',
#  '6:37 pm',
#  '6:54 pm',
#  '7:35 am',
#  '12:54 pm',
#  '12:55 pm',
#  '12:55 pm',
#  '12:58 pm',
#  '1:59 pm',
#  '7:49 pm',
#  '7:50 pm',
#  '7:55 pm',
#  '4:17 pm',
#  '5:36 pm',
#  '5:39 pm',
#  '5:51 pm',
#  '5:51 pm',
#  '8:30 pm',
#  '8:34 pm',
#  '8:39 pm',
#  '8:41 pm',
#  '3:06 pm',
#  '3:07 pm',
#  '3:08 pm',
#  '3:08 pm',
#  '3:08 pm',
#  '3:09 pm',
#  '3:09 pm',
#  '3:09 pm',
#  '3:09 pm',
#  '3:09 pm',
#  '3:10 pm',
#  '3:10 pm',
#  '3:11 pm',
#  '3:11 pm',
#  '3:29 pm',
#  '3:29 pm',
#  '3:30 pm',
#  '12:02 pm',
#  '12:07 pm',
#  '12:10 pm',
#  '1:22 pm',
#  '2:53 pm',
#  '9:36 am',
#  '9:56 am',
#  '10:06 am',
#  '9:48 pm',
#  '1:41 pm',
#  '1:53 pm',
#  '1:57 pm',
#  '2:05 pm',
#  '2:07 pm',
#  '2:37 pm',
#  '4:16 pm',
#  '4:20 pm',
#  '4:20 pm',
#  '4:20 pm',
#  '4:20 pm',
#  '4:20 pm',
#  '4:21 pm',
#  '4:21 pm',
#  '4:21 pm',
#  '4:21 pm',
#  '4:21 pm',
#  '4:22 pm',
#  '4:22 pm',
#  '4:22 pm',
#  '4:22 pm',
#  '4:22 pm',
#  '4:22 pm',
#  '4:23 pm',
#  '4:23 pm',
#  '4:23 pm',
#  '4:24 pm',
#  '4:25 pm',
#  '4:26 pm',
#  '4:26 pm',
#  '4:33 pm',
#  '4:37 pm',
#  '4:37 pm',
#  '4:41 pm',
#  '4:42 pm',
#  '5:55 pm',
#  '6:18 pm',
#  '6:22 pm',
#  '6:26 pm',
#  '6:28 pm',
#  '8:44 pm',
#  '8:52 pm',
#  '8:53 pm',
#  '8:53 pm',
#  '8:54 pm',
#  '8:54 pm',
#  '8:54 pm',
#  '8:54 pm',
#  '8:55 pm',
#  '8:55 pm',
#  '8:55 pm',
#  '8:56 pm',
#  '8:56 pm',
#  '8:57 pm',
#  '10:22 pm',
#  '10:23 pm',
#  '10:23 pm',
#  '6:56 am',
#  '6:58 am',
#  '6:59 am',
#  '9:57 am',
#  '9:58 am',
#  '10:05 am',
#  '10:12 am',
#  '10:23 am',
#  '10:28 am',
#  '10:34 am',
#  '2:23 pm',
#  '2:24 pm',
#  '2:27 pm',
#  '2:37 pm',
#  '2:38 pm',
#  '4:30 pm',
#  '9:45 am',
#  '5:55 pm',
#  '9:19 pm',
#  '1:06 am',
#  '1:11 am',
#  '5:05 am',
#  '5:10 am',
#  '5:10 am',
#  '5:27 am',
#  '5:27 am',
#  '6:00 am',
#  '7:06 pm',
#  '7:06 pm',
#  '7:08 pm',
#  '7:08 pm',
#  '7:14 pm',
#  '7:14 pm',
#  '7:34 pm',
#  '7:36 pm',
#  '9:36 pm',
#  '10:39 pm',
#  '10:41 pm',
#  '2:53 pm',
#  ...]

# %%
date = [msgs[i].split(',')[0] for i in range(len(msgs))]
len(date)
name = [msgs[i].split('-')[1].split(':')[0] for i in range(len(msgs))]
len(name)
content = []
for i in range(len(msgs)):
  try:
    content.append(msgs[i].split(':')[2])
  except IndexError:
    content.append('Missing Text')
len(content)
# Out:
# 2023

# %% [markdown]
# Now we can finally use the pandas library to merge our date, time, name and content data into a Dataframe named df using the code below:

# %%
df = pd.DataFrame(list(zip(date, time, name, content)), columns = ['Date', 'Time', 'Name', 'Content'])
df
# Out:
#             Date      Time                                               Name  \
# 0     04/08/2022   2:12 pm                         Messages and calls are end
# 1     04/08/2022  12:05 pm   +234 813 215 5650 created group "CodePlateau4...
# 2     04/08/2022   3:02 pm          +234 814 838 1223 added +234 802 253 0435
# 3     04/08/2022   3:18 pm          +234 814 838 1223 added +234 806 892 9315
# 4     04/08/2022   3:41 pm                                  +234 803 570 5272
# ...          ...       ...                                                ...
# 2018  24/10/2022   7:23 pm                                  +234 803 570 5272
# 2019  24/10/2022   7:23 pm                                  +234 816 739 8525
# 2020  24/10/2022   7:24 pm                                  +234 816 739 8525
# 2021  24/10/2022   7:24 pm                                  +234 701 936 6781
# 2022  24/10/2022   7:24 pm                                  +234 701 936 6781
#
#                                                 Content
# 0                                          Missing Text
# 1                                          Missing Text
# 2                                          Missing Text
# 3                                          Missing Text
# 4          Please, can you send the document for today?
# ...                                                 ...
# 2018   Oho! U wan do us the more we see the less we ...
# 2019                                    <Media omitted>
# 2020                                    <Media omitted>
# 2021                Na why we no want make u see sef...
# 2022                                        See ur face
#
# [2023 rows x 4 columns]

# %%
df = df[df["Content"]!='Missing Text']
df.reset_index(inplace=True, drop=True)
df
# Out:
#             Date      Time                  Name  \
# 0     04/08/2022   3:41 pm     +234 803 570 5272
# 1     04/08/2022   4:20 pm     +234 806 451 1186
# 2     04/08/2022   4:28 pm     +234 806 234 7970
# 3     04/08/2022  10:11 pm   Jabezy Code Plateau
# 4     05/08/2022  10:56 am     +234 802 253 0435
# ...          ...       ...                   ...
# 2010  24/10/2022   7:23 pm     +234 803 570 5272
# 2011  24/10/2022   7:23 pm     +234 816 739 8525
# 2012  24/10/2022   7:24 pm     +234 816 739 8525
# 2013  24/10/2022   7:24 pm     +234 701 936 6781
# 2014  24/10/2022   7:24 pm     +234 701 936 6781
#
#                                                 Content
# 0          Please, can you send the document for today?
# 1                                             Calm down
# 2                 Thanks for the link and for adding me
# 3                                       <Media omitted>
# 4                                       <Media omitted>
# ...                                                 ...
# 2010   Oho! U wan do us the more we see the less we ...
# 2011                                    <Media omitted>
# 2012                                    <Media omitted>
# 2013                Na why we no want make u see sef...
# 2014                                        See ur face
#
# [2015 rows x 4 columns]

# %% [markdown]
# We will create additional columns by taking advantage of built-in functions in pandas. First, let us create a Datetime column by merging Date and Time columns and using the pd.to_datetime function:

# %%
df['DateTime'] = pd.to_datetime(df['Date'] + ' ' + df['Time'])
df['DateTime']
# Out:
# 0      2022-04-08 15:41:00
# 1      2022-04-08 16:20:00
# 2      2022-04-08 16:28:00
# 3      2022-04-08 22:11:00
# 4      2022-05-08 10:56:00
#                ...
# 2010   2022-10-24 19:23:00
# 2011   2022-10-24 19:23:00
# 2012   2022-10-24 19:24:00
# 2013   2022-10-24 19:24:00
# 2014   2022-10-24 19:24:00
# Name: DateTime, Length: 2015, dtype: datetime64[ns]

# %%
df['weekday'] = df['DateTime'].apply(lambda x: x.day_name())
df
# Out:
#             Date      Time                  Name  \
# 0     04/08/2022   3:41 pm     +234 803 570 5272
# 1     04/08/2022   4:20 pm     +234 806 451 1186
# 2     04/08/2022   4:28 pm     +234 806 234 7970
# 3     04/08/2022  10:11 pm   Jabezy Code Plateau
# 4     05/08/2022  10:56 am     +234 802 253 0435
# ...          ...       ...                   ...
# 2010  24/10/2022   7:23 pm     +234 803 570 5272
# 2011  24/10/2022   7:23 pm     +234 816 739 8525
# 2012  24/10/2022   7:24 pm     +234 816 739 8525
# 2013  24/10/2022   7:24 pm     +234 701 936 6781
# 2014  24/10/2022   7:24 pm     +234 701 936 6781
#
#                                                 Content            DateTime  \
# 0          Please, can you send the document for today? 2022-04-08 15:41:00
# 1                                             Calm down 2022-04-08 16:20:00
# 2                 Thanks for the link and for adding me 2022-04-08 16:28:00
# 3                                       <Media omitted> 2022-04-08 22:11:00
# 4                                       <Media omitted> 2022-05-08 10:56:00
# ...                                                 ...                 ...
# 2010   Oho! U wan do us the more we see the less we ... 2022-10-24 19:23:00
# 2011                                    <Media omitted> 2022-10-24 19:23:00
# 2012                                    <Media omitted> 2022-10-24 19:24:00
# 2013                Na why we no want make u see sef... 2022-10-24 19:24:00
# 2014                                        See ur face 2022-10-24 19:24:00
#
#      weekday
# 0     Friday
# 1     Friday
# 2     Friday
# 3     Friday
# 4     Sunday
# ...      ...
# 2010  Monday
# 2011  Monday
# 2012  Monday
# 2013  Monday
# 2014  Monday
#
# [2015 rows x 6 columns]

# %% [markdown]
# We will split our Content column to create new columns showing the number of letters and words contained in each message. We will call these columns Letter_count and Word_count respectively.

# %%
df['Letter_Count'] = df['Content'].apply(lambda s : len(s))
df['Word_Count'] = df['Content'].apply(lambda s : len(s.split(' ')))

# %%
df['Hour'] = df['Time'].apply(lambda x : x.split(':')[0]) 
# The first token of a value in the Time Column contains the hour (Eg., "12" in "12:15")

# %%
#print first five rows of our dataframe
df.head()
# Out:
#          Date      Time                  Name  \
# 0  04/08/2022   3:41 pm     +234 803 570 5272
# 1  04/08/2022   4:20 pm     +234 806 451 1186
# 2  04/08/2022   4:28 pm     +234 806 234 7970
# 3  04/08/2022  10:11 pm   Jabezy Code Plateau
# 4  05/08/2022  10:56 am     +234 802 253 0435
#
#                                          Content            DateTime weekday  \
# 0   Please, can you send the document for today? 2022-04-08 15:41:00  Friday
# 1                                      Calm down 2022-04-08 16:20:00  Friday
# 2          Thanks for the link and for adding me 2022-04-08 16:28:00  Friday
# 3                                <Media omitted> 2022-04-08 22:11:00  Friday
# 4                                <Media omitted> 2022-05-08 10:56:00  Sunday
#
#    Letter_Count  Word_Count Hour
# 0            45           9    3
# 1            10           3    4
# 2            38           9    4
# 3            16           3   10
# 4            16           3   10

# %%
#saving to csv format
df.to_csv("WhatsappChat.csv")
